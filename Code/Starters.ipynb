# %% [markdown]
# A file for installing some of the libraries needed for DTSC 2301

# %%
# !pip install --upgrade pip

# %%
pip install numpy

# %%
pip install scipy

# %%
pip install pandas

# %%
pip install matplotlib

# %%
# !pip install nbconvert
#pip3 install nbconvert

# %%
# !pip install seaborn
#!python -m pip install seaborn

# %%
# !pip install statsmodels
#!python -m pip install statsmodels

# %%
# !pip install scikit-learn
# !python -m pip install scikit-learn

# %%
# !python -m pip install scipy
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\mschuck1\appdata\roaming\python\python313\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\mschuck1\appdata\roaming\python\python313\site-packages (from scipy) (2.4.1)
# Requirement already satisfied: scipy in c:\users\mschuck1\appdata\roaming\python\python313\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\mschuck1\appdata\roaming\python\python313\site-packages (from scipy) (2.4.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\mschuck1\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Homework code
# Code below will make your pdf not run off the page.  Put it at the very top of your Jupyter Notebook for your homework solutions.

# %% [markdown]
# <style>
# .container { width: 80% !important; margin: auto; }
# div.cell { padding: 10px 15% 10px 15%; }
# </style>
