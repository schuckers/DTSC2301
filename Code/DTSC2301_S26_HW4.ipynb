# %% [markdown]
# <style>
# .container { width: 80% !important; margin: auto; }
# div.cell { padding: 10px 15% 10px 15%; }
# </style>

# %% [markdown]
# ## DTSC 2301 Spring 2026 Homework #4
#
# Turn in your assignment via Gradescope
#
# Due 2/15/26, 11:59pm

# %% [markdown]
# #### Question 1
#
# For the Ames Housing Data [<https://webpages.charlotte.edu/mschuck1/classes/DTSC2301/Data/Ames_house_prices.csv>], fit a linear model that predicts the *SalePrice* of a house from the *GarageArea*.   Evaluate whether or not
# a linear model is appropriate for the relationship between these two features.

# %% [markdown]
# ### Question 2
#
# What are the limitations of the model that you generated in the previous question?  Why is it important to be transparent about the limitations and assumptions of your model?

# %% [markdown]
# #### Question 3
# Using the same data and variables from Question 1, fit a cubic spline with knots at 200, 400, 600 and 800.  Plot that spline on a scatterplot of the data.

# %% [markdown]
# #### Question 4
# Using the same data and variables from Question 1, fit a cubic regression to these data.  Create a scatterplot for these data and plot the prediction line on that plot.

# %% [markdown]
# #### Question 5
# Find and compare the RMSE's of the models from Questions 1, 3 and 4.  Comment on which model is the best among these.

# %% [markdown]
# #### Question 6
# For the next two questions read the following articles that can be found on Canvas: [FairnessAgeOfAlgorithm.pdf](https://instructure.charlotte.edu/courses/253945/modules/items/7771940) and [UnbiasedNotFairness.pdf](https://instructure.charlotte.edu/courses/253945/modules/items/7771941)
#  Write a paragraph, between 100 and 250 words, that compares and contrasts the views of algorithmic fairness in these two articles.

# %% [markdown]
# #### Question 7
# Again using the two articles from the previous question, give a new example --- that is, not one from either article --- of a prediction model that could be 'unbiased' by one measure but still unfair.
