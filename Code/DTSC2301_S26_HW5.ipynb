# %% [markdown]
# <style>
# .container { width: 80% !important; margin: auto; }
# div.cell { padding: 10px 15% 10px 15%; }
# </style>

# %% [markdown]
# ## DTSC 2301 Spring 2026 Homework #4
#
# Turn in your assignment via Gradescope
#
# Due 2/22/26, 11:59pm

# %% [markdown]
# #### Question 1
#
# Complete your course evaluations [( http://myevals.charlotte.edu)] if you so choose.  But your full name below to acknowledge that you have read this question.

# %% [markdown]
# ### Question 2
#
# Take a 15 to 20 minute break in nature without any electronics or screens.  Report below two things that made you smile during this break.

# %% [markdown]
# #### Question 3
# Reach out to someone you've been meaning to connect with.  Tell them how important they are to you.  Below describe your relationship to them (e.g friend, cousin, etc.)
