# %% [markdown]
# ### Notes on DTSC 2301 Project 1
#
# + You will upload three different files to Gradescope: a Part I report file, two powerpoint slides file and a Part II report file.  All of those should be pdf's.
#
# + The project is due on 2/13/26 at 11:59pm.
#
# + For Part II, you just need to respond to the four prompts as part of your response.
#
# + We are changing the requirement for the Powerpoint Slides to 2 slides.  The first slide should be title and names of your group member.  Second slide should be information about your project.
